# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Z.csv')
df1 = pd.read_csv('Z-Exp.csv')
df
# Out:
#        α  Z(α)-R1/0.5  Z(α)-R2/0.5  Z(α)-R3/0.5  Z(α)-R4/0.5  Z(α)-R6/0.5  \
# 0   0.05     0.140601         0.19        0.247     0.309700     0.164255
# 1   0.10     0.273606         0.36        0.456     0.557486     0.315371
# 2   0.15     0.398591         0.51        0.629     0.749700     0.452989
# 3   0.20     0.515085         0.64        0.768     0.892343     0.576717
# 4   0.25     0.622556         0.75        0.875     0.991071     0.686127
# 5   0.30     0.720402         0.84        0.952     1.051200     0.780749
# 6   0.35     0.807935         0.91        1.001     1.077700     0.860063
# 7   0.40     0.884359         0.96        1.024     1.075200     0.923490
# 8   0.45     0.948746         0.99        1.023     1.047986     0.970382
# 9   0.50     1.000000         1.00        1.000     1.000000     1.000000
# 10  0.55     1.036803         0.99        0.957     0.934843     1.011501
# 11  0.60     1.057542         0.96        0.896     0.855771     1.003900
# ...

# %%
plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
plt.scatter(df['α'],df['Z(α)-R1/0.5'])
plt.scatter(df['α'],df['Z(α)-R2/0.5'])
plt.scatter(df['α'],df['Z(α)-R3/0.5'])
plt.scatter(df['α'],df['Z(α)-R4/0.5'])
plt.scatter(df['α'],df['Z(α)-R5/0.5'])
plt.scatter(df['α'],df['Z(α)-R6/0.5'])
plt.scatter(df['α'],df['Z(α)-D1/0.5'])
plt.scatter(df['α'],df['Z(α)-D2/0.5'])
plt.scatter(df['α'],df['Z(α)-D3/0.5'])
plt.scatter(df['α'],df['Z(α)-A1/0.5'])
plt.scatter(df['α'],df['Z(α)-F2/0.5'])
plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.legend()

# %%
df1
# Out:
#        α  Z(α)1-0.5  Z(α)1-0.5.1  Z(α)1-0.5.2  Z(α)1-0.5.3  Z(α)1-0.5.4  \
# 0   0.05   0.313889     0.113842     0.151439     0.233465     0.284882
# 1   0.10   0.444131     0.211515     0.322989     0.328679     0.402025
# 2   0.15   0.729307     0.331940     0.478813     0.497643     0.597842
# 3   0.20   1.076192     0.421076     0.707915     0.614696     0.735938
# 4   0.25   1.220604     0.541856     0.845827     0.769903     0.824756
# 5   0.30   1.412574     0.577079     0.547235     0.852096     0.953865
# 6   0.35   1.535533     0.847133     1.153016     0.961390     1.065765
# 7   0.40   1.695613     0.627420     0.967108     0.945790     1.220350
# 8   0.45   1.583833     0.716102     1.068805     1.050648     1.283992
# 9   0.50   1.295161     1.003103     1.069473     1.191140     1.389746
# 10  0.55   0.997836     0.829065     0.854214     1.218527     1.502905
# 11  0.60   0.956818     0.821187     0.550068     1.353196     1.394668
# ...

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
# plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
# plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
# plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
# plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
# plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
# plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
# plt.scatter(df['α'],df['Z(α)-R2/0.5'])
plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# plt.scatter(df['α'],df['Z(α)-R5/0.5'])
plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
# plt.scatter(df['α'],df['Z(α)-D2/0.5'])
# plt.scatter(df['α'],df['Z(α)-D3/0.5'])
# plt.scatter(df['α'],df['Z(α)-A1/0.5'])
# plt.scatter(df['α'],df['Z(α)-F2/0.5'])
plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
# plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)1-0.5'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)1-0.5'],color = 'black')
plt.legend()
plt.ylabel('Z(α)/(Z(α))0.5')
plt.xlabel('α')
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5])
# plt.title('Straw-with Ni-CaO-Si2O4 Catalyst',fontweight='bold')
# Out:
# ([<matplotlib.axis.YTick at 0x20bb9c72f40>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
# plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
# plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
# plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
# plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
# plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
# plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
# plt.scatter(df['α'],df['Z(α)-R2/0.5'])
# plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# plt.scatter(df['α'],df['Z(α)-R5/0.5'])
plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
# plt.scatter(df['α'],df['Z(α)-D2/0.5'])
plt.scatter(df['α'],df['Z(α)-D3/0.5'])
# plt.scatter(df['α'],df['Z(α)-A1/0.5'])
# plt.scatter(df['α'],df['Z(α)-F2/0.5'])
# plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)1-0.5.1'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)1-0.5.1'],color = 'black')
plt.legend()
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5])
plt.ylabel('Z(α)/(Z(α))0.5')
plt.xlabel('α')
# plt.title('Straw-without Catalyst',fontweight='bold')
# Out:
# Text(0.5, 0, 'α')

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
# plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
# plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
# plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
# plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
# plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
# plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
plt.scatter(df['α'],df['Z(α)-R2/0.5'])
# plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# plt.scatter(df['α'],df['Z(α)-R5/0.5'])
plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
# plt.scatter(df['α'],df['Z(α)-D2/0.5'])
# plt.scatter(df['α'],df['Z(α)-D3/0.5'])
# plt.scatter(df['α'],df['Z(α)-A1/0.5'])
plt.scatter(df['α'],df['Z(α)-F2/0.5'])
# plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)1-0.5.2'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)1-0.5.2'],color = 'black')
plt.legend()
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5])
# plt.title('Straw-with Ni-Ca2SiO4 Catalyst',fontweight='bold')
plt.ylabel('Z(α)/(Z(α))0.5')
plt.xlabel('α')
# Out:
# Text(0.5, 0, 'α')

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
# plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
# plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
# plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
# plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
# plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
plt.scatter(df['α'],df['Z(α)-R2/0.5'])
# plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# plt.scatter(df['α'],df['Z(α)-R5/0.5'])
plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
plt.scatter(df['α'],df['Z(α)-D2/0.5'])
plt.scatter(df['α'],df['Z(α)-D3/0.5'])
# plt.scatter(df['α'],df['Z(α)-A1/0.5'])
plt.scatter(df['α'],df['Z(α)-F2/0.5'])
# plt.scatter(df['α'],df['Z(α)-F3/0.5'])
# plt.scatter(df['α'],df['Z(α)-F4/0.5'])
# plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)1-0.5.3'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)1-0.5.3'],color = 'black')
plt.legend()
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5])
# plt.title('Sawdust-without Catalyst',fontweight='bold')
plt.ylabel('Z(α)/(Z(α))0.5')
plt.xlabel('α')
# Out:
# Text(0.5, 0, 'α')

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
# plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# # plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
# plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
# plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
# plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
# plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
# plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
# plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
plt.scatter(df['α'],df['Z(α)-R2/0.5'])
# plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# # plt.scatter(df['α'],df['Z(α)-R5/0.5'])
# plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
plt.scatter(df['α'],df['Z(α)-D2/0.5'])
# plt.scatter(df['α'],df['Z(α)-D3/0.5'])
# plt.scatter(df['α'],df['Z(α)-A1/0.5'])
# plt.scatter(df['α'],df['Z(α)-F2/0.5'])
# plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
# plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)1-0.5.4'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)1-0.5.4'],color = 'black')
plt.legend()
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5])
# plt.title('Sawdust-with Ni-CaO-Si2O4 Catalyst',fontweight='bold')
plt.ylabel('Z(α)/(Z(α))0.5')
plt.xlabel('α')
# Out:
# Text(0.5, 0, 'α')

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
# plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
# plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
# plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
# plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
# plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
# plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
plt.scatter(df['α'],df['Z(α)-R2/0.5'])
# plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# plt.scatter(df['α'],df['Z(α)-R5/0.5'])
# plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
# plt.scatter(df['α'],df['Z(α)-D2/0.5'])
plt.scatter(df['α'],df['Z(α)-D3/0.5'])
# plt.scatter(df['α'],df['Z(α)-A1/0.5'])
# plt.scatter(df['α'],df['Z(α)-F2/0.5'])
# plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)1-0.5.5'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)1-0.5.5'],color = 'black')
plt.legend()
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5])
# plt.title('Sawdust-with Ni-Ca2SiO4 Catalyst',fontweight='bold')
plt.ylabel('Z(α)/(Z(α))0.5')
plt.xlabel('α')
# Out:
# Text(0.5, 0, 'α')

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
# plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
# plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
# plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
# plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
# plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
plt.scatter(df['α'],df['Z(α)-R2/0.5'])
# plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# plt.scatter(df['α'],df['Z(α)-R5/0.5'])
plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
# plt.scatter(df['α'],df['Z(α)-D2/0.5'])
plt.scatter(df['α'],df['Z(α)-D3/0.5'])
plt.scatter(df['α'],df['Z(α)-A1/0.5'])
# plt.scatter(df['α'],df['Z(α)-F2/0.5'])
# plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
# plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)1-0.5.6'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)1-0.5.6'],color = 'black')
plt.legend()
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5])
# plt.title('Cellulose-without Catalyst',fontweight='bold')
plt.ylabel('Z(α)/(Z(α))0.5')
plt.xlabel('α')
# Out:
# Text(0.5, 0, 'α')

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
# plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
# plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
# plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
# plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
# plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
plt.scatter(df['α'],df['Z(α)-R2/0.5'])
# plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# plt.scatter(df['α'],df['Z(α)-R5/0.5'])
plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
plt.scatter(df['α'],df['Z(α)-D2/0.5'])
plt.scatter(df['α'],df['Z(α)-D3/0.5'])
# plt.scatter(df['α'],df['Z(α)-A1/0.5'])
# plt.scatter(df['α'],df['Z(α)-F2/0.5'])
# plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
# plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)1-0.5.7'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)1-0.5.7'],color = 'black')
plt.legend()
plt.xticks([0.2,0.4,0.6,0.8,1,1.2])
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5])
# plt.title('Cellulose-with Ni-CaO-Si2O4 Catalyst',fontweight='bold')
plt.ylabel('Z(α)/(Z(α))0.5')
plt.xlabel('α')
# Out:
# Text(0.5, 0, 'α')

# %%
# plt.plot(df['α'],df['Z(α)-R1/0.5'],label='R1')
# plt.plot(df['α'],df['Z(α)-R2/0.5'],label='R2')
plt.plot(df['α'],df['Z(α)-R3/0.5'],label='R3')
# plt.plot(df['α'],df['Z(α)-R4/0.5'],label='R4')
# plt.plot(df['α'],df['Z(α)-R5/0.5'],label='R5')
plt.plot(df['α'],df['Z(α)-R6/0.5'],label='R6')
# plt.plot(df['α'],df['Z(α)-D1/0.5'],label='D1')
plt.plot(df['α'],df['Z(α)-D2/0.5'],label='D2')
plt.plot(df['α'],df['Z(α)-D3/0.5'],label='D3')
plt.plot(df['α'],df['Z(α)-A1/0.5'],label='A1')
# plt.plot(df['α'],df['Z(α)-F2/0.5'],label='F2')
# plt.plot(df['α'],df['Z(α)-F3/0.5'],label='F3')
plt.plot(df['α'],df['Z(α)-F4/0.5'],label='F4')
# plt.plot(df['α'],df['Z(α)-P2/0.5'],label='P2')
# plt.scatter(df['α'],df['Z(α)-R1/0.5'])
plt.scatter(df['α'],df['Z(α)-R2/0.5'])
# plt.scatter(df['α'],df['Z(α)-R3/0.5'])
# plt.scatter(df['α'],df['Z(α)-R4/0.5'])
# plt.scatter(df['α'],df['Z(α)-R5/0.5'])
plt.scatter(df['α'],df['Z(α)-R6/0.5'])
# plt.scatter(df['α'],df['Z(α)-D1/0.5'])
plt.scatter(df['α'],df['Z(α)-D2/0.5'])
plt.scatter(df['α'],df['Z(α)-D3/0.5'])
plt.scatter(df['α'],df['Z(α)-A1/0.5'])
# plt.scatter(df['α'],df['Z(α)-F2/0.5'])
# plt.scatter(df['α'],df['Z(α)-F3/0.5'])
plt.scatter(df['α'],df['Z(α)-F4/0.5'])
# plt.scatter(df['α'],df['Z(α)-P2/0.5'])
plt.plot(df1['α'],df1['Z(α)-0.5'],label='Exp',color = 'black')
plt.scatter(df1['α'],df1['Z(α)-0.5'],color = 'black')
legend_properties = {'weight':'bold'}
plt.xticks([0.2,0.4,0.6,0.8,1,1.2],fontweight='bold')
plt.yticks([0.25,0.50,0.75,1.00,1.25,1.50,1.75,2.00,2.25,2.5],fontweight='bold')
plt.legend(prop=legend_properties)
plt.title('Cellulose with NiCa$_2$SiO$_4$ Catalyst',fontweight='bold')
plt.ylabel('Z(α)/(Z(α))$_{0.5}$',fontweight='bold',fontsize='12')
plt.xlabel('α',fontweight='bold')
# Out:
# Text(0.5, 0, 'α')
