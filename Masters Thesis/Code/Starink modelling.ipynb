# %%
import pandas as pd

# %%
df1 = pd.read_csv('0.05-S.csv')
df2 = pd.read_csv('0.1-s.csv')
df3 = pd.read_csv('0.15-s.csv')
df4 = pd.read_csv('0.2-s.csv')
df5 = pd.read_csv('0.25-s.csv')
df6 = pd.read_csv('0.3-s.csv')
df7 = pd.read_csv('0.35-s.csv')
df8 = pd.read_csv('0.4-s.csv')
df9 = pd.read_csv('0.45-s.csv')
df10 = pd.read_csv('0.5-s.csv')
df11 = pd.read_csv('0.55-s.csv')
df12 = pd.read_csv('0.6-s.csv')
df13 = pd.read_csv('0.65-s.csv')
df14 = pd.read_csv('0.7-s.csv')
df15 = pd.read_csv('0.75-s.csv')
df16 = pd.read_csv('0.8-s.csv')
df17 = pd.read_csv('0.85-s.csv')
df18 = pd.read_csv('0.9-s.csv')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
import numpy as np
# %matplotlib inline

x=df1['A']
y=df1['B']
plt.scatter(df1['A'],df1.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df2['A']
y=df2['B']
plt.scatter(df2['A'],df2.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['A']
y=df3['B']
plt.scatter(df3['A'],df3.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['A']
y=df4['B']
plt.scatter(df4['A'],df4.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['A']
y=df5['B']
plt.scatter(df5['A'],df5.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['A']
y=df5['B']
plt.scatter(df5['A'],df5.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['A']
y=df6['B']
plt.scatter(df6['A'],df6.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['A']
y=df7['B']
plt.scatter(df7['A'],df7.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['A']
y=df8['B']
plt.scatter(df8['A'],df8.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['A']
y=df9['B']
plt.scatter(df9['A'],df9.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['A']
y=df10['B']
plt.scatter(df10['A'],df10.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['A']
y=df11['B']
plt.scatter(df11['A'],df11.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['A']
y=df12['B']
plt.scatter(df12['A'],df12.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['A']
y=df13['B']
plt.scatter(df13['A'],df13.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['A']
y=df14['B']
plt.scatter(df14['A'],df14.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['A']
y=df15['B']
plt.scatter(df15['A'],df15.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['A']
y=df16['B']
plt.scatter(df16['A'],df16.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['A']
y=df17['B']
plt.scatter(df17['A'],df17.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['A']
y=df18['B']
plt.scatter(df18['A'],df18.B,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-straw without catalyst')

plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')
plt.legend(loc= 'upper left', fontsize='large')

# %%
plt.scatter(df1['A'],df1.B)
plt.scatter(df2['A'],df2.B)
plt.scatter(df3['A'],df3.B)
plt.scatter(df4['A'],df4.B)
plt.scatter(df5['A'],df5.B)
plt.scatter(df6['A'],df6.B)
plt.scatter(df7['A'],df7.B)
plt.scatter(df8['A'],df8.B)
plt.scatter(df9['A'],df9.B)
plt.scatter(df10['A'],df10.B)
plt.scatter(df11['A'],df11.B)
plt.scatter(df12['A'],df12.B)
plt.scatter(df13['A'],df13.B)
plt.scatter(df14['A'],df14.B)
plt.scatter(df15['A'],df15.B)
plt.scatter(df16['A'],df16.B)
plt.scatter(df17['A'],df17.B)
plt.scatter(df18['A'],df18.B)
plt.plot(df1['A'],df1.B)
plt.plot(df2['A'],df2.B)
plt.plot(df3['A'],df3.B)
plt.plot(df4['A'],df4.B)
plt.plot(df5['A'],df5.B)
plt.plot(df6['A'],df6.B)
plt.plot(df7['A'],df7.B)
plt.plot(df8['A'],df8.B)
plt.plot(df9['A'],df9.B)
plt.plot(df10['A'],df10.B)
plt.plot(df11['A'],df11.B)
plt.plot(df12['A'],df12.B)
plt.plot(df13['A'],df13.B)
plt.plot(df14['A'],df14.B)
plt.plot(df15['A'],df15.B)
plt.plot(df16['A'],df16.B)
plt.plot(df17['A'],df17.B)
plt.plot(df18['A'],df18.B)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
# %matplotlib inline
plt.scatter(df18['C'],df18.D,color='black',marker='^')


x=df1['C']
y=df1['D']
plt.scatter(df1['C'],df1.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df2['C']
y=df2['D']
plt.scatter(df2['C'],df2.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['C']
y=df3['D']
plt.scatter(df3['C'],df3.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['C']
y=df4['D']
plt.scatter(df4['C'],df4.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['C']
y=df5['D']
plt.scatter(df5['C'],df5.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['C']
y=df5['D']
plt.scatter(df5['C'],df5.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['C']
y=df6['D']
plt.scatter(df6['C'],df6.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['C']
y=df7['D']
plt.scatter(df7['C'],df7.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['C']
y=df8['D']
plt.scatter(df8['C'],df8.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['C']
y=df9['D']
plt.scatter(df9['C'],df9.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['C']
y=df10['D']
plt.scatter(df10['C'],df10.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['C']
y=df11['D']
plt.scatter(df11['C'],df11.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['C']
y=df12['D']
plt.scatter(df12['C'],df12.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['C']
y=df13['D']
plt.scatter(df13['C'],df13.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['C']
y=df14['D']
plt.scatter(df14['C'],df14.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['C']
y=df15['D']
plt.scatter(df15['C'],df15.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['C']
y=df16['D']
plt.scatter(df16['C'],df16.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['C']
y=df17['D']
plt.scatter(df17['C'],df17.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['C']
y=df18['D']
plt.scatter(df18['C'],df18.D,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-straw with Ni-CaO-Si2O4')

plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')
plt.legend(loc='upper left',fontsize='large')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
# %matplotlib inline

plt.scatter(df18['E'],df18.F,color='black',marker='^')


x=df1['E']
y=df1['F']
plt.scatter(df1['E'],df1.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df2['E']
y=df2['F']
plt.scatter(df2['E'],df2.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['E']
y=df3['F']
plt.scatter(df3['E'],df3.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['E']
y=df4['F']
plt.scatter(df4['E'],df4.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['E']
y=df5['F']
plt.scatter(df5['E'],df5.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['E']
y=df5['F']
plt.scatter(df5['E'],df5.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['E']
y=df6['F']
plt.scatter(df6['E'],df6.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['E']
y=df7['F']
plt.scatter(df7['E'],df7.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['E']
y=df8['F']
plt.scatter(df8['E'],df8.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['E']
y=df9['F']
plt.scatter(df9['E'],df9.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['E']
y=df10['F']
plt.scatter(df10['E'],df10.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['E']
y=df11['F']
plt.scatter(df11['E'],df11.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['E']
y=df12['F']
plt.scatter(df12['E'],df12.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['E']
y=df13['F']
plt.scatter(df13['E'],df13.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['E']
y=df14['F']
plt.scatter(df14['E'],df14.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['E']
y=df15['F']
plt.scatter(df15['E'],df15.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['E']
y=df16['F']
plt.scatter(df16['E'],df16.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['E']
y=df17['F']
plt.scatter(df17['E'],df17.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['E']
y=df18['F']
plt.scatter(df18['E'],df18.F,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-straw with NiCa2SiO4')

plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')
plt.legend(loc='upper left',fontsize='large')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
# %matplotlib inline
plt.scatter(df1['G'],df1.H,color='black',marker='^')

x=df1['G']
y=df1['H']
plt.scatter(df1['G'],df1.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df2['G']
y=df2['H']
plt.scatter(df2['G'],df2.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['G']
y=df3['H']
plt.scatter(df3['G'],df3.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['G']
y=df4['H']
plt.scatter(df4['G'],df4.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['G']
y=df5['H']
plt.scatter(df5['G'],df5.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['G']
y=df5['H']
plt.scatter(df5['G'],df5.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['G']
y=df6['H']
plt.scatter(df6['G'],df6.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['G']
y=df7['H']
plt.scatter(df7['G'],df7.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['G']
y=df8['H']
plt.scatter(df8['G'],df8.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['G']
y=df9['H']
plt.scatter(df9['G'],df9.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['G']
y=df10['H']
plt.scatter(df10['G'],df10.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['G']
y=df11['H']
plt.scatter(df11['G'],df11.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['G']
y=df12['H']
plt.scatter(df12['G'],df12.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['G']
y=df13['H']
plt.scatter(df13['G'],df13.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['G']
y=df14['H']
plt.scatter(df14['G'],df14.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['G']
y=df15['H']
plt.scatter(df15['G'],df15.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['G']
y=df16['H']
plt.scatter(df16['G'],df16.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['G']
y=df17['H']
plt.scatter(df17['G'],df17.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['G']
y=df18['H']
plt.scatter(df18['G'],df18.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-sawdust without catalyst')
plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')
plt.xticks([0.0014,0.0015,0.0016,0.0017,0.0018])
plt.yticks([-9.6,-9.4,-9.2,-9.0,-8.8,-8.6,-8.4,-8.2,-8.0])
plt.legend(loc='upper left',fontsize='large')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
# %matplotlib inline
plt.scatter( df18['I'],df18.J,color='black',marker='^')

x=df1['I']
y=df1['J']
plt.scatter(df1['I'],df1.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df2['I']
y=df2['J']
plt.scatter(df2['I'],df2.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['I']
y=df3['J']
plt.scatter(df3['I'],df3.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['I']
y=df4['J']
plt.scatter(df4['I'],df4.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['I']
y=df5['J']
plt.scatter(df5['I'],df5.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['I']
y=df5['J']
plt.scatter(df5['I'],df5.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['I']
y=df6['J']
plt.scatter(df6['I'],df6.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['I']
y=df7['J']
plt.scatter(df7['I'],df7.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['I']
y=df8['J']
plt.scatter(df8['I'],df8.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['I']
y=df9['J']
plt.scatter(df9['I'],df9.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['I']
y=df10['J']
plt.scatter(df10['I'],df10.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['I']
y=df11['J']
plt.scatter(df11['I'],df11.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['I']
y=df12['J']
plt.scatter(df12['I'],df12.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['I']
y=df13['H']
plt.scatter(df13['I'],df13.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['I']
y=df14['J']
plt.scatter(df14['I'],df14.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['I']
y=df15['J']
plt.scatter(df15['I'],df15.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['I']
y=df16['J']
plt.scatter(df16['I'],df16.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['I']
y=df17['J']
plt.scatter(df17['I'],df17.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['I']
y=df18['J']
plt.scatter(df18['I'],df18.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-Sawdust with Ni-CaO-Ca2SiO4')
plt.yticks([-10.0,-9.8,-9.6,-9.4,-9.2,-9.0,-8.8,-8.6,-8.4,-8.2,-8.0])
plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')
plt.legend(loc='upper left',fontsize='large')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
# %matplotlib inline
plt.scatter( df18['K'],df18.L,color='black',marker='^')
x=df1['K']
y=df1['L']
plt.scatter(df1['K'],df1.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df2['K']
y=df2['L']
plt.scatter(df2['K'],df2.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['K']
y=df3['L']
plt.scatter(df3['K'],df3.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['K']
y=df4['L']
plt.scatter(df4['K'],df4.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['K']
y=df5['L']
plt.scatter(df5['K'],df5.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['K']
y=df5['L']
plt.scatter(df5['K'],df5.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['K']
y=df6['L']
plt.scatter(df6['K'],df6.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['K']
y=df7['L']
plt.scatter(df7['K'],df7.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['K']
y=df8['L']
plt.scatter(df8['K'],df8.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['K']
y=df9['L']
plt.scatter(df9['K'],df9.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['K']
y=df10['L']
plt.scatter(df10['K'],df10.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['K']
y=df11['L']
plt.scatter(df11['K'],df11.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['K']
y=df12['L']
plt.scatter(df12['K'],df12.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['K']
y=df13['H']
plt.scatter(df13['K'],df13.H,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['K']
y=df14['J']
plt.scatter(df14['K'],df14.J,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['K']
y=df15['L']
plt.scatter(df15['K'],df15.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['K']
y=df16['L']
plt.scatter(df16['K'],df16.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['K']
y=df17['L']
plt.scatter(df17['K'],df17.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['K']
y=df18['L']
plt.scatter(df18['K'],df18.L,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-sawdust with Ni-Ca2SiO4')
plt.yticks([-9.8,-9.6,-9.4,-9.2,-9.0,-8.8,-8.6,-8.4,-8.2,-8.0])
plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')
plt.legend(loc='upper left',fontsize='large')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
# %matplotlib inline
plt.scatter(df18['M'],df18.N,color='black',marker='^')


x=df1['M']
y=df1['N']
plt.scatter(df1['M'],df1.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df2['M']
y=df2['N']
plt.scatter(df2['M'],df2.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['M']
y=df3['N']
plt.scatter(df3['M'],df3.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['M']
y=df4['N']
plt.scatter(df4['M'],df4.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['M']
y=df5['N']
plt.scatter(df5['M'],df5.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['M']
y=df5['N']
plt.scatter(df5['M'],df5.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['M']
y=df6['N']
plt.scatter(df6['M'],df6.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['M']
y=df7['N']
plt.scatter(df7['M'],df7.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['M']
y=df8['N']
plt.scatter(df8['M'],df8.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['M']
y=df9['N']
plt.scatter(df9['M'],df9.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['M']
y=df10['N']
plt.scatter(df10['M'],df10.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['M']
y=df11['N']
plt.scatter(df11['M'],df11.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['M']
y=df12['N']
plt.scatter(df12['M'],df12.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['M']
y=df13['N']
plt.scatter(df13['M'],df13.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['M']
y=df14['N']
plt.scatter(df14['M'],df14.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['M']
y=df15['N']
plt.scatter(df15['M'],df15.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['M']
y=df16['N']
plt.scatter(df16['M'],df16.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['M']
y=df17['N']
plt.scatter(df17['M'],df17.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['M']
y=df18['N']
plt.scatter(df18['M'],df18.N,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-Cellulose without catalyst')

plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')
plt.xticks([0.0015,0.00155,0.0016,0.00165,0.0017])
plt.yticks([-9.8,-9.6,-9.4,-9.2,-9.0,-8.8,-8.6,-8.4,-8.2,-8.0])
plt.legend(loc='upper left',fontsize='large')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
# %matplotlib inline




x=df1['O']
y=df1['P']
plt.scatter(df1['O'],df1.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-Cellulose with Ni-CaO-Si2O4')
x=df2['O']
y=df2['P']
plt.scatter(df2['O'],df2.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['O']
y=df3['P']
plt.scatter(df3['O'],df3.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['O']
y=df4['P']
plt.scatter(df4['O'],df4.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['O']
y=df5['P']
plt.scatter(df5['O'],df5.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['O']
y=df5['P']
plt.scatter(df5['O'],df5.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['O']
y=df6['P']
plt.scatter(df6['O'],df6.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['O']
y=df7['P']
plt.scatter(df7['O'],df7.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['O']
y=df8['P']
plt.scatter(df8['O'],df8.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['O']
y=df9['P']
plt.scatter(df9['O'],df9.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['O']
y=df10['P']
plt.scatter(df10['O'],df10.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['O']
y=df11['P']
plt.scatter(df11['O'],df11.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['O']
y=df12['P']
plt.scatter(df12['O'],df12.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['O']
y=df13['P']
plt.scatter(df13['O'],df13.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['O']
y=df14['P']
plt.scatter(df14['O'],df14.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['O']
y=df15['P']
plt.scatter(df15['O'],df15.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['O']
y=df16['P']
plt.scatter(df16['O'],df16.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['O']
y=df17['P']
plt.scatter(df17['O'],df17.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['O']
y=df18['P']
plt.scatter(df18['O'],df18.P,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
plt.yticks([-9.8,-9.6,-9.4,-9.2,-9.0,-8.8,-8.6,-8.4,-8.2])
plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')

plt.legend(loc='upper left',fontsize='large')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))

plt.scatter(df1['Q'],df1.R,color='black',marker='^')


x=df1['Q']
y=df1['R']
plt.scatter(df1['Q'],df1.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black',label='Starink-Cellulose with Ni-Ca2SiO4')
x=df2['Q']
y=df2['R']
plt.scatter(df2['Q'],df2.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df3['Q']
y=df3['R']
plt.scatter(df3['Q'],df3.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df4['Q']
y=df4['R']
plt.scatter(df4['Q'],df4.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['Q']
y=df5['R']
plt.scatter(df5['Q'],df5.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df5['Q']
y=df5['R']
plt.scatter(df5['Q'],df5.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df6['Q']
y=df6['R']
plt.scatter(df6['Q'],df6.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df7['Q']
y=df7['R']
plt.scatter(df7['Q'],df7.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df8['Q']
y=df8['R']
plt.scatter(df8['Q'],df8.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df9['Q']
y=df9['R']
plt.scatter(df9['Q'],df9.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df10['Q']
y=df10['R']
plt.scatter(df10['Q'],df10.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df11['Q']
y=df11['R']
plt.scatter(df11['Q'],df11.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df12['Q']
y=df12['R']
plt.scatter(df12['Q'],df12.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df13['Q']
y=df13['R']
plt.scatter(df13['Q'],df13.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df14['Q']
y=df14['R']
plt.scatter(df14['Q'],df14.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df15['Q']
y=df15['R']
plt.scatter(df15['Q'],df15.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df16['Q']
y=df16['R']
plt.scatter(df16['Q'],df16.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df17['Q']
y=df17['R']
plt.scatter(df17['Q'],df17.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
x=df18['Q']
y=df18['R']
plt.scatter(df18['Q'],df18.R,color='black',marker='^')
z = np.polyfit(x, y,1)
p = np.poly1d(z)
plt.plot(x,p(x),color = 'black')
plt.yticks([-9.6,-9.4,-9.2,-9.0,-8.8,-8.6,-8.4,-8.2])
plt.xlabel('1/T',fontsize='14')
plt.ylabel('ln(β/T^1.92)',fontsize='14')
plt.legend(loc='upper left',fontsize='large')
